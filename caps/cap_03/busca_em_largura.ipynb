# %% [markdown]
# ## BFS (Busca em largura)
# > Conceito: O nó raiz é expandido em seguida os sucessores desse nó e assim por diante. Em geral todos os nós de uma dada profundidade são expandidos antés que se passe para os nós do próximo nível;
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Criado arquivo python **grafo_romenia** para ajudar e evitar repetição de código

# %%
import networkx as nx
from grafo_romenia import criar_grafo_romenia

G = criar_grafo_romenia()

print(G.nodes(data=True))
print(G.edges(data=True))
# Out:
# [('Arad', {'pos': (91, 492)}), ('Bucharest', {'pos': (400, 327)}), ('Craiova', {'pos': (253, 288)}), ('Drobeta', {'pos': (165, 299)}), ('Eforie', {'pos': (562, 293)}), ('Fagaras', {'pos': (305, 449)}), ('Giurgiu', {'pos': (375, 270)}), ('Hirsova', {'pos': (534, 350)}), ('Iasi', {'pos': (473, 506)}), ('Lugoj', {'pos': (165, 379)}), ('Mehadia', {'pos': (168, 339)}), ('Neamt', {'pos': (406, 537)}), ('Oradea', {'pos': (131, 571)}), ('Pitesti', {'pos': (320, 368)}), ('Rimnicu', {'pos': (233, 410)}), ('Sibiu', {'pos': (207, 457)}), ('Timisoara', {'pos': (94, 410)}), ('Urziceni', {'pos': (456, 350)}), ('Vaslui', {'pos': (509, 444)}), ('Zerind', {'pos': (108, 531)})]
# ...

# %%
no_raiz = 'Arad'
arvore = nx.bfs_tree(G, source=no_raiz)

print("Nós em árvore BFS:", list(arvore.nodes()))
print("Arestas em árvore BFS:", list(arvore.edges()))

# %% [markdown]
# ---

# %% [markdown]
# ### Visualização do processo BFS (caps\cap_03\frames\BFS.gif)

# %% [markdown]
# ![bfs_animation.gif](attachment:bfs_animation.gif)
