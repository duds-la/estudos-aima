# %% [markdown]
# ## Conteúdos Abordados no capítulo:
#
# -   Nó ✅
# -   Busca em Largura ✅
# -   Busca de Custo Uniforme ✅
# -   Busca em Profundidade ✅
# -   Busca em Profundidade Gulosa ✅
# -   Busca A*
# -   Escalada de Encosta
# -   Recozimento Simulado
# -   Algoritmo Genético
# -   Busca em Grafos AND-OR
# -   Agente DFS Online
# -   Agente LRTA*
